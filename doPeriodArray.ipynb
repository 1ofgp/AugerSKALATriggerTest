# %%
import numpy as np
import matplotlib.pyplot as plt
print("import done")
# Out:
# import done

# %%
def generate_poisson_times(rate, max_time):
    time_deltas = np.random.exponential(1 / rate, size = 2 * 3600 * rate)
    times = np.cumsum(time_deltas)
    return times[times <= max_time]

# %%
periodArray = np.loadtxt("/home/novikov/cobaltMount/taxi_data/auger2024-25/trig_period/UUB_diffs_insert.txt", dtype=int)

# %%
nbEvents =60000
periodArray = []
for i in range(nbEvents):
    periodArray.append(10000)

# %%
periodArray = (np.int32((np.diff(generate_poisson_times(100, 600))*1e6)))
print(periodArray)
# Out:
# [ 7785  7619  1249 ...  7552 17041  2071]

# %%
bins = np.arange(0, 100000, 100)
plt.hist(periodArray, bins =bins)
# plt.yscale('log')
# plt.plot(s)
plt.xlim(0, 20000)
plt.show()

# %%
print(len(periodArray))
# Out:
# 60000

# %%
print(np.sum(periodArray < 75))
# Out:
# 451

# %%
for i in range(len(periodArray)):
    print(periodArray[i], ", ")
# Out:
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# 10000 ,
# ...

# %%
# 1000000
# 100000
# 10000
# 5200
# 2400
# 1100
# 770
# 510
# 230
# 120

periodArray1 = []
for i in range(0, 100):
    periodArray1.append(1000000) 
for i in range(100, 200):
    periodArray1.append(100000) 
for i in range(200, 300):
    periodArray1.append(10000) 
 
for i in range(300, 400):
    periodArray1.append(5200) 
    
for i in range(400, 500):
    periodArray1.append(2400) 

for i in range(500, 600):
    periodArray1.append(1100) 

for i in range(600, 700):
    periodArray1.append(770) 

for i in range(700, 800):
    periodArray1.append(510) 
   
for i in range(800, 900):
    periodArray1.append(230) 
  
for i in range(900, 1000):
    periodArray1.append(120)

# %%
periodArray2 = []
for i in range(500):
    periodArray2.append(int(1e7)) 
for i in range(500):
    periodArray2.append(int(1e6))
for i in range(500):
    periodArray2.append(int(1e5))
for i in range(500):
    periodArray2.append(int(1e4))
for i in range(500):
    periodArray2.append(int(1e3))

# %%
plt.plot(periodArray2)
plt.yscale('log')

# %%
print("#include <Arduino.h>")
print("int periodArray[] = {")
for i in range(len(periodArray)):
    print(periodArray[i], ", ")

print("};")
# Out:
# #include <Arduino.h>
# int periodArray[] = {
# 36712 ,
# 11147 ,
# 20540 ,
# 37774 ,
# 4353 ,
# 7376 ,
# 1943 ,
# 4645 ,
# 43623 ,
# 21265 ,
# 1099 ,
# 18165 ,
# 14628 ,
# 17155 ,
# 1785 ,
# 26765 ,
# 20915 ,
# 30460 ,
# 4807 ,
# 24750 ,
# 19303 ,
# 11843 ,
# 42031 ,
# 22575 ,
# 10699 ,
# 17061 ,
# 19221 ,
# 23679 ,
# 3215 ,
# 11567 ,
# 1493 ,
# 7237 ,
# 23347 ,
# 660 ,
# 25924 ,
# 52300 ,
# 58867 ,
# 40096 ,
# 3377 ,
# 31093 ,
# 213 ,
# 33875 ,
# 4348 ,
# 6386 ,
# 15142 ,
# 10165 ,
# 14977 ,
# 6417 ,
# 485 ,
# 22121 ,
# 27740 ,
# 50902 ,
# 29547 ,
# 17944 ,
# 21885 ,
# 10006 ,
# 10027 ,
# 12866 ,
# 1502 ,
# 40289 ,
# 15935 ,
# 13508 ,
# 36730 ,
# 62750 ,
# 31299 ,
# 5047 ,
# 18336 ,
# 17999 ,
# 41258 ,
# 15018 ,
# 6913 ,
# 18607 ,
# 5118 ,
# 7391 ,
# 35757 ,
# 3174 ,
# 34091 ,
# 9611 ,
# 3847 ,
# 10408 ,
# 25700 ,
# 44458 ,
# 48295 ,
# 8113 ,
# 17405 ,
# 22251 ,
# 1223 ,
# 43386 ,
# 14761 ,
# 31145 ,
# 6220 ,
# 31447 ,
# 34040 ,
# 17969 ,
# 6823 ,
# 71034 ,
# 765 ,
# 47020 ,
# ...
